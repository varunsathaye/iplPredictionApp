# %%
import pandas as pd
import numpy as np

# %%
matches=pd.read_csv('matches.csv')
deliveries=pd.read_csv('deliveries.csv')

# %%
matches.head(10)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...

# %%
deliveries.head(120)
# Out:
#      match_id  inning           batting_team                 bowling_team  \
# 0      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4      335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ..        ...     ...                    ...                          ...
# 115    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 116    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 117    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 118    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 119    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
#
#      over  ball           batter     bowler      non_striker  batsman_runs  \
# ...

# %%
deliveries.shape
# Out:
# (260920, 17)

# %%
matches.shape
# Out:
# (1095, 20)

# %%
matches=matches[['id','city','team1','team2','winner','target_runs','method']]

# %%
matches['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
matches=matches[matches['method']!='D/L']

# %%
matches.head(20)
# Out:
#         id        city                        team1  \
# 0   335982   Bangalore  Royal Challengers Bangalore
# 1   335983  Chandigarh              Kings XI Punjab
# 2   335984       Delhi             Delhi Daredevils
# 3   335985      Mumbai               Mumbai Indians
# 4   335986     Kolkata        Kolkata Knight Riders
# 5   335987      Jaipur             Rajasthan Royals
# 6   335988   Hyderabad              Deccan Chargers
# 7   335989     Chennai          Chennai Super Kings
# 8   335990   Hyderabad              Deccan Chargers
# 9   335991  Chandigarh              Kings XI Punjab
# 10  335992   Bangalore  Royal Challengers Bangalore
# 11  335993     Chennai          Chennai Super Kings
# 12  335994      Mumbai               Mumbai Indians
# 13  335995  Chandigarh              Kings XI Punjab
# 14  335996   Bangalore  Royal Challengers Bangalore
# 15  335997     Kolkata        Kolkata Knight Riders
# 16  335998       Delhi             Delhi Daredevils
# ...

# %%
matches['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams=['Royal Challengers Bengaluru','Punjab Kings','Delhi Capitals','Mumbai Indians','Kolkata Knight Riders','Rajasthan Royals','Sunrisers Hyderabad','Lucknow Super Giants', 'Gujarat Titans','Chennai Super Kings']

# %%
matches['team1']=matches['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
matches['team2']=matches['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

matches['team1']=matches['team1'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
matches['team2']=matches['team2'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

matches['team1']=matches['team1'].str.replace('Kings XI Punjab','Punjab Kings')
matches['team2']=matches['team2'].str.replace('Kings XI Punjab','Punjab Kings')

matches['team1']=matches['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matches['team2']=matches['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
matches=matches[matches['team1'].isin(teams)]
matches=matches[matches['team2'].isin(teams)]

# %%
matches.head()
# Out:
#        id        city                        team1  \
# 0  335982   Bangalore  Royal Challengers Bengaluru
# 1  335983  Chandigarh                 Punjab Kings
# 2  335984       Delhi               Delhi Capitals
# 3  335985      Mumbai               Mumbai Indians
# 4  335986     Kolkata        Kolkata Knight Riders
#
#                          team2                       winner  target_runs  \
# 0        Kolkata Knight Riders        Kolkata Knight Riders        223.0
# 1          Chennai Super Kings          Chennai Super Kings        241.0
# 2             Rajasthan Royals             Delhi Daredevils        130.0
# 3  Royal Challengers Bengaluru  Royal Challengers Bangalore        166.0
# 4          Sunrisers Hyderabad        Kolkata Knight Riders        111.0
#
#   method
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
matches=matches.drop(['method'],axis=1)

# %%
matches.head()
# Out:
#        id        city                        team1  \
# 0  335982   Bangalore  Royal Challengers Bengaluru
# 1  335983  Chandigarh                 Punjab Kings
# 2  335984       Delhi               Delhi Capitals
# 3  335985      Mumbai               Mumbai Indians
# 4  335986     Kolkata        Kolkata Knight Riders
#
#                          team2                       winner  target_runs
# 0        Kolkata Knight Riders        Kolkata Knight Riders        223.0
# 1          Chennai Super Kings          Chennai Super Kings        241.0
# 2             Rajasthan Royals             Delhi Daredevils        130.0
# 3  Royal Challengers Bengaluru  Royal Challengers Bangalore        166.0
# 4          Sunrisers Hyderabad        Kolkata Knight Riders        111.0

# %%
deliveries.head(50)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 7     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 10    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 11    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
matches=matches.drop(['team1','team2'],axis=1)

# %%
matches.head()
# Out:
#        id        city                       winner  target_runs
# 0  335982   Bangalore        Kolkata Knight Riders        223.0
# 1  335983  Chandigarh          Chennai Super Kings        241.0
# 2  335984       Delhi             Delhi Daredevils        130.0
# 3  335985      Mumbai  Royal Challengers Bangalore        166.0
# 4  335986     Kolkata        Kolkata Knight Riders        111.0

# %%
matches.rename(columns={'id': 'match_id'}, inplace=True)

# %%
matches.head()
# Out:
#    match_id        city                       winner  target_runs
# 0    335982   Bangalore        Kolkata Knight Riders        223.0
# 1    335983  Chandigarh          Chennai Super Kings        241.0
# 2    335984       Delhi             Delhi Daredevils        130.0
# 3    335985      Mumbai  Royal Challengers Bangalore        166.0
# 4    335986     Kolkata        Kolkata Knight Riders        111.0

# %%
delivery_df=matches.merge(deliveries,on='match_id')

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 0         335982  Bangalore  Kolkata Knight Riders        223.0       1
# 1         335982  Bangalore  Kolkata Knight Riders        223.0       1
# 2         335982  Bangalore  Kolkata Knight Riders        223.0       1
# 3         335982  Bangalore  Kolkata Knight Riders        223.0       1
# 4         335982  Bangalore  Kolkata Knight Riders        223.0       1
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                  batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df.shape
# Out:
# (111721, 20)

# %%
delivery_df['total_runs'] = pd.to_numeric(delivery_df['total_runs'], errors='coerce')  # Coerce bad values to NaN if needed
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs'].cumsum()
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\2950266432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['total_runs'] = pd.to_numeric(delivery_df['total_runs'], errors='coerce')  # Coerce bad values to NaN if needed
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\2950266432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs'].cumsum()

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['runs_left']=delivery_df['target_runs']-delivery_df['current_score']
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\3387445532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left']=delivery_df['target_runs']-delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['balls_left']=120-(delivery_df['over']*6+delivery_df['ball'])
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\3788185712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left']=120-(delivery_df['over']*6+delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
delivery_df['player_dismissed']=delivery_df['player_dismissed'].astype('int')
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\1753340267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna("0")
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\1753340267.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
# ...

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128    335982  Bangalore  Kolkata Knight Riders        223.0       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... extra_runs total_runs  extras_type  is_wicket  player_dismissed  \
# ...

# %%
delivery_df['is_wicket'].dtype
# Out:
# dtype('int64')

# %%
delivery_df['is_wicket'] = pd.to_numeric(delivery_df['is_wicket'], errors='coerce')  # Coerce bad values to NaN if needed
delivery_df['is_wicket'] = delivery_df.groupby('match_id')['is_wicket'].cumsum()
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\1157391560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['is_wicket'] = pd.to_numeric(delivery_df['is_wicket'], errors='coerce')  # Coerce bad values to NaN if needed
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\1157391560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['is_wicket'] = delivery_df.groupby('match_id')['is_wicket'].cumsum()

# %%
delivery_df.head(50)
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 129    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 130    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 131    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 132    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 133    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 134    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 135    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 136    335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...

# %%
delivery_df['wickets_left']=10-delivery_df['is_wicket']
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\2203161881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets_left']=10-delivery_df['is_wicket']

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\1289864394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['rrr']=(delivery_df['runs_left']*6)/(delivery_df['balls_left'])
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\297266893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr']=(delivery_df['runs_left']*6)/(delivery_df['balls_left'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)
# Out:
# C:\Users\satha\AppData\Local\Temp\ipykernel_20856\2671046774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result']=delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 230977   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230978   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230979   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230980   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 230981   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df=delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','target_runs','crr','rrr','result']]

# %%
delivery_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 230977        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230978        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230979        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230980        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230981        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# ...

# %%
final_df=delivery_df

# %%
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 230977        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230978        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230979        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230980        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230981        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# ...

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#         batting_team           bowling_team     city  runs_left  balls_left  \
# 224101  Punjab Kings  Kolkata Knight Riders  Kolkata       65.0          35
#
#         wickets_left  target_runs        crr        rrr  result
# 224101             8        262.0  13.905882  11.142857       1

# %%
final_df.dropna(inplace=True)

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
X=final_df.drop(['result'],axis=1)
y=final_df['result']

# %%
X.head()
# Out:
#                        batting_team           bowling_team       city  \
# 123090  Royal Challengers Bangalore        Kings XI Punjab  Bengaluru
# 131109             Rajasthan Royals    Chennai Super Kings     Jaipur
# 122585          Chennai Super Kings  Kolkata Knight Riders    Chennai
# 197193          Sunrisers Hyderabad       Rajasthan Royals  Hyderabad
# 99934         Kolkata Knight Riders    Chennai Super Kings    Chennai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# 123090      109.0          79             8        156.0   6.878049
# 131109      118.0          81             8        177.0   9.076923
# 122585      150.0          97            10        203.0  13.826087
# 197193       77.0           1             2        204.0   6.403361
# 99934        66.0          61             7        135.0   7.016949
#
#                rrr
# 123090    8.278481
# 131109    8.740741
# 122585    9.278351
# 197193  462.000000
# 99934     6.491803

# %%
y.head()
# Out:
# 123090    1
# 131109    1
# 122585    1
# 197193    0
# 99934     0
# Name: result, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer([
    ('trf',OneHotEncoder(drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline([
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8069675827044472

# %%
import pickle

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
final_df
# Out:
#                        batting_team           bowling_team        city  \
# 123090  Royal Challengers Bangalore        Kings XI Punjab   Bengaluru
# 131109             Rajasthan Royals    Chennai Super Kings      Jaipur
# 122585          Chennai Super Kings  Kolkata Knight Riders     Chennai
# 197193          Sunrisers Hyderabad       Rajasthan Royals   Hyderabad
# 99934         Kolkata Knight Riders    Chennai Super Kings     Chennai
# ...                             ...                    ...         ...
# 36185               Kings XI Punjab         Mumbai Indians  Chandigarh
# 74821              Rajasthan Royals       Delhi Daredevils      Jaipur
# 215268  Royal Challengers Bengaluru           Punjab Kings   Bengaluru
# 98344   Royal Challengers Bangalore    Chennai Super Kings   Bangalore
# 171989               Delhi Capitals    Sunrisers Hyderabad       Dubai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# ...

# %%
final_df['city'].unique()
# Out:
# array(['Bengaluru', 'Jaipur', 'Chennai', 'Hyderabad', 'Mumbai',
#        'Navi Mumbai', 'Sharjah', 'Port Elizabeth', 'Kolkata',
#        'Chandigarh', 'Bangalore', 'Pune', 'Dharamsala', 'Cuttack',
#        'Delhi', 'Nagpur', 'Visakhapatnam', 'Abu Dhabi', 'Dubai', 'Durban',
#        'Mohali', 'Ahmedabad', 'Raipur', 'Centurion', 'Ranchi', 'Lucknow',
#        'Indore', 'Johannesburg', 'Cape Town', 'Guwahati', 'East London',
#        'Bloemfontein', 'Kimberley'], dtype=object)

# %%
pipe
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import joblib
joblib.dump(pipe,'pipe.pkl')
# Out:
# ['pipe.pkl']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.0
